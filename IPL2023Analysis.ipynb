# %% [markdown]
# <a href="https://colab.research.google.com/github/RuchiV78/IPL-2023/blob/main/IPL2023Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3937ef1e-6fdf-4d9c-af25-269e125d5271" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3937ef1e-6fdf-4d9c-af25-269e125d5271">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load Data

# %%
iplball = pd.read_csv('IPL_Ball_by_Ball_2022.csv')

# %%
iplmatch = pd.read_csv('IPL_Matches_2022.csv')

# %%
iplball.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
iplball.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
[iplball[(iplball['BattingTeam']=='Gujarat Titans')]]
# Out:
# [            ID  innings  overs  ballnumber        batter        bowler  \
#  120    1312200        2      0           1       WP Saha      TA Boult
#  121    1312200        2      0           2       WP Saha      TA Boult
#  122    1312200        2      0           3       WP Saha      TA Boult
#  123    1312200        2      0           4  Shubman Gill      TA Boult
#  124    1312200        2      0           5  Shubman Gill      TA Boult
#  ...        ...      ...    ...         ...           ...           ...
#  17178  1304050        2     18           6     R Tewatia  PVD Chameera
#  17179  1304050        2     19           1     A Manohar    Avesh Khan
#  17180  1304050        2     19           2     A Manohar    Avesh Khan
#  17181  1304050        2     19           3     A Manohar    Avesh Khan
#  17182  1304050        2     19           4     R Tewatia    Avesh Khan
#
#          non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
iplball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17912 entries, 0 to 17911
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 17912 non-null  int64
#  1   innings            17912 non-null  int64
#  2   overs              17912 non-null  int64
#  3   ballnumber         17912 non-null  int64
#  4   batter             17912 non-null  object
#  5   bowler             17912 non-null  object
#  6   non-striker        17912 non-null  object
#  7   extra_type         1050 non-null   object
#  8   batsman_run        17912 non-null  int64
#  9   extras_run         17912 non-null  int64
#  10  total_run          17912 non-null  int64
#  11  non_boundary       17912 non-null  int64
#  12  isWicketDelivery   17912 non-null  int64
#  13  player_out         912 non-null    object
#  14  kind               912 non-null    object
#  15  fielders_involved  704 non-null    object
# ...

# %%
inningID = iplball[(iplball['BattingTeam']=='Gujarat Titans')]

# %%
print(iplball['ID'].where(iplball['BattingTeam']=='Gujarat Titans'))
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 17907   NaN
# 17908   NaN
# 17909   NaN
# 17910   NaN
# 17911   NaN
# Name: ID, Length: 17912, dtype: float64

# %%
iplball.shape
# Out:
# (17912, 17)

# %%
iplmatch.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
iplmatch.head()
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29    2022        Final
# 1  1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25    2022   Eliminator
# 3  1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
iplmatch['ID'].where((iplmatch['Team1']=='Gujarat Titans') | (iplmatch['Team2']=='Gujarat Titans'))
# Out:
# 0     1312200.0
# 1           NaN
# 2           NaN
# 3     1312197.0
# 4           NaN
#         ...
# 69          NaN
# 70    1304050.0
# 71          NaN
# 72          NaN
# 73          NaN
# Name: ID, Length: 74, dtype: float64

# %%
iplGT = iplmatch.loc[iplmatch['ID'].where((iplmatch['Team1']=='Gujarat Titans') | (iplmatch['Team2']=='Gujarat Titans')).notnull()]

# %%
iplGT
# Out:
#          ID         City        Date  Season  MatchNumber  \
# 0   1312200    Ahmedabad  2022-05-29    2022        Final
# 3   1312197      Kolkata  2022-05-24    2022  Qualifier 1
# 7   1304113       Mumbai  2022-05-19    2022           67
# 12  1304108       Mumbai  2022-05-15    2022           62
# 17  1304103         Pune  2022-05-10    2022           57
# 23  1304097       Mumbai  2022-05-06    2022           51
# 26  1304094  Navi Mumbai  2022-05-03    2022           48
# 31  1304089       Mumbai  2022-04-30    2022           43
# 34  1304086       Mumbai  2022-04-27    2022           40
# 39  1304081  Navi Mumbai  2022-04-23    2022           35
# 45  1304075         Pune  2022-04-17    2022           29
# 50  1304070       Mumbai  2022-04-14    2022           24
# 53  1304067       Mumbai  2022-04-11    2022           21
# 58  1304062       Mumbai  2022-04-08    2022           16
# 64  1304056         Pune  2022-04-02    2022           10
# ...

# %%
iplGT.shape
# Out:
# (16, 20)

# %%
iplGT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 0 to 70
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               16 non-null     int64
#  1   City             16 non-null     object
#  2   Date             16 non-null     object
#  3   Season           16 non-null     int64
#  4   MatchNumber      16 non-null     object
#  5   Team1            16 non-null     object
#  6   Team2            16 non-null     object
#  7   Venue            16 non-null     object
#  8   TossWinner       16 non-null     object
#  9   TossDecision     16 non-null     object
#  10  SuperOver        16 non-null     object
#  11  WinningTeam      16 non-null     object
#  12  WonBy            16 non-null     object
#  13  Margin           16 non-null     int64
#  14  method           0 non-null      float64
#  15  Player_of_Match  16 non-null     object
#  16  Team1Players     16 non-null     object
# ...

# %%
iplballGT = iplball.loc[iplball['ID'].isin(iplGT.ID)]

# %%
iplballGT
# Out:
#             ID  innings  overs  ballnumber       batter          bowler  \
# 0      1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1      1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2      1312200        1      0           3   JC Buttler  Mohammed Shami
# 3      1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4      1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...        ...      ...    ...         ...          ...             ...
# 17178  1304050        2     18           6    R Tewatia    PVD Chameera
# 17179  1304050        2     19           1    A Manohar      Avesh Khan
# 17180  1304050        2     19           2    A Manohar      Avesh Khan
# 17181  1304050        2     19           3    A Manohar      Avesh Khan
# 17182  1304050        2     19           4    R Tewatia      Avesh Khan
#
#        non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
iplballGT.ID.value_counts()
# Out:
# 1304081    253
# 1312197    252
# 1304086    251
# 1304062    247
# 1304056    247
# 1304097    246
# 1304075    246
# 1304070    246
# 1304067    246
# 1304050    245
# 1304108    244
# 1304089    244
# 1304113    237
# 1312200    233
# 1304094    229
# 1304103    212
# Name: ID, dtype: int64

# %%
#GT batsman total runs
dfbatsman = iplballGT

# %%
dfbatsman.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
GTbatting = dfbatsman.loc[dfbatsman['BattingTeam'] == "Gujarat Titans"]

# %%
GTbatting
# Out:
#             ID  innings  overs  ballnumber        batter        bowler  \
# 120    1312200        2      0           1       WP Saha      TA Boult
# 121    1312200        2      0           2       WP Saha      TA Boult
# 122    1312200        2      0           3       WP Saha      TA Boult
# 123    1312200        2      0           4  Shubman Gill      TA Boult
# 124    1312200        2      0           5  Shubman Gill      TA Boult
# ...        ...      ...    ...         ...           ...           ...
# 17178  1304050        2     18           6     R Tewatia  PVD Chameera
# 17179  1304050        2     19           1     A Manohar    Avesh Khan
# 17180  1304050        2     19           2     A Manohar    Avesh Khan
# 17181  1304050        2     19           3     A Manohar    Avesh Khan
# 17182  1304050        2     19           4     R Tewatia    Avesh Khan
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
iplballGT.loc[iplballGT['BattingTeam']=="Gujarat Titans",['batter','batsman_run']].groupby('batter').sum().sort_values(by='batsman_run',ascending=False).style.background_gradient(cmap='gray_r')
# Out:
# <style type="text/css">
# #T_c6685_row0_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_c6685_row1_col0 {
#   background-color: #020202;
#   color: #f1f1f1;
# }
# #T_c6685_row2_col0 {
#   background-color: #030303;
#   color: #f1f1f1;
# }
# #T_c6685_row3_col0 {
#   background-color: #595959;
#   color: #f1f1f1;
# }
# #T_c6685_row4_col0 {
#   background-color: #8d8d8d;
#   color: #f1f1f1;
# }
# #T_c6685_row5_col0 {
#   background-color: #adadad;
#   color: #000000;
# }
# #T_c6685_row6_col0 {
#   background-color: #b3b3b3;
#   color: #000000;
# }
# #T_c6685_row7_col0 {
#   background-color: #c7c7c7;
#   color: #000000;
# }
# #T_c6685_row8_col0 {
#   background-color: #d0d0d0;
#   color: #000000;
# }
# #T_c6685_row9_col0 {
#   background-color: #f6f6f6;
#   color: #000000;
# }
# #T_c6685_row10_col0, #T_c6685_row11_col0 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_c6685_row12_col0 {
#   background-color: #fefefe;
#   color: #000000;
# }
# ...
